# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler

# Load datasets
customers = pd.read_csv('/content/Customers.csv')
products = pd.read_csv('/content/Products.csv')
transactions = pd.read_csv('/content/Transactions.csv')


# Merge datasets
transactions_products = pd.merge(transactions, products, on="ProductID")
customer_data = pd.merge(transactions_products, customers, on="CustomerID")

# Aggregate customer profiles
customer_profiles = customer_data.groupby("CustomerID").agg({
    "TotalValue": "sum",             # Total spending by customer
    "Quantity": "sum",               # Total quantity purchased by customer
    "Price_y": "mean",               # Average price of products bought
    "Category": lambda x: x.mode()[0],  # Most common product category
}).reset_index()

# Rename columns for clarity
customer_profiles.rename(columns={"Price_y": "AvgPrice"}, inplace=True)

# Add region information from customers dataset
customer_profiles = pd.merge(customer_profiles, customers[["CustomerID", "Region"]], on="CustomerID")

# One-hot encode categorical features (e.g., Region, Category)
customer_profiles_encoded = pd.get_dummies(customer_profiles, columns=["Region", "Category"], drop_first=True)

# Standardize numerical features
scaler = StandardScaler()
numerical_features = ["TotalValue", "Quantity", "AvgPrice"]
customer_profiles_encoded[numerical_features] = scaler.fit_transform(customer_profiles_encoded[numerical_features])

# Compute pairwise similarity
similarity_matrix = cosine_similarity(customer_profiles_encoded.drop("CustomerID", axis=1))

# Create a DataFrame for similarity
similarity_df = pd.DataFrame(similarity_matrix, index=customer_profiles["CustomerID"], columns=customer_profiles["CustomerID"])

# Recommend top 3 similar customers for each of the first 20 customers
top_20_customers = customer_profiles["CustomerID"][:20]
lookalike_map = {}

for customer_id in top_20_customers:
    # Sort similarity scores in descending order, exclude the customer itself
    similar_customers = similarity_df[customer_id].sort_values(ascending=False).drop(customer_id).head(3)
    lookalike_map[customer_id] = list(similar_customers.items())

# Save results to Lookalike.csv
lookalike_results = []

for cust_id, recommendations in lookalike_map.items():
    for rec_cust_id, score in recommendations:
        lookalike_results.append({"CustomerID": cust_id, "SimilarCustomerID": rec_cust_id, "SimilarityScore": score})

lookalike_df = pd.DataFrame(lookalike_results)
lookalike_df.to_csv("Lookalike.csv", index=False)

print("Lookalike recommendations have been saved to Lookalike.csv!")
# Print the lookalike recommendations
for cust_id, recommendations in lookalike_map.items():
    print(f"CustomerID: {cust_id}")
    for rec_cust_id, score in recommendations:
        print(f"  SimilarCustomerID: {rec_cust_id}, SimilarityScore: {score:.4f}")
    print("-" * 50)
# Out:
# Lookalike recommendations have been saved to Lookalike.csv!
# CustomerID: C0001
#   SimilarCustomerID: C0181, SimilarityScore: 0.9347
#   SimilarCustomerID: C0120, SimilarityScore: 0.8975
#   SimilarCustomerID: C0184, SimilarityScore: 0.8641
# --------------------------------------------------
# CustomerID: C0002
#   SimilarCustomerID: C0088, SimilarityScore: 0.9848
#   SimilarCustomerID: C0077, SimilarityScore: 0.9007
#   SimilarCustomerID: C0144, SimilarityScore: 0.8962
# --------------------------------------------------
# CustomerID: C0003
#   SimilarCustomerID: C0031, SimilarityScore: 0.8639
#   SimilarCustomerID: C0025, SimilarityScore: 0.8622
#   SimilarCustomerID: C0052, SimilarityScore: 0.8448
# --------------------------------------------------
# CustomerID: C0004
#   SimilarCustomerID: C0165, SimilarityScore: 0.9826
#   SimilarCustomerID: C0153, SimilarityScore: 0.9128
#   SimilarCustomerID: C0169, SimilarityScore: 0.9081
# --------------------------------------------------
# CustomerID: C0005
#   SimilarCustomerID: C0140, SimilarityScore: 0.9899
#   SimilarCustomerID: C0186, SimilarityScore: 0.9758
#   SimilarCustomerID: C0146, SimilarityScore: 0.8996
# --------------------------------------------------
# CustomerID: C0006
#   SimilarCustomerID: C0187, SimilarityScore: 0.9497
#   SimilarCustomerID: C0168, SimilarityScore: 0.9371
#   SimilarCustomerID: C0126, SimilarityScore: 0.9150
# --------------------------------------------------
# CustomerID: C0007
#   SimilarCustomerID: C0146, SimilarityScore: 0.9959
#   SimilarCustomerID: C0115, SimilarityScore: 0.9630
#   SimilarCustomerID: C0186, SimilarityScore: 0.9317
# --------------------------------------------------
# CustomerID: C0008
#   SimilarCustomerID: C0136, SimilarityScore: 0.8470
#   SimilarCustomerID: C0018, SimilarityScore: 0.8206
#   SimilarCustomerID: C0065, SimilarityScore: 0.8107
# --------------------------------------------------
# CustomerID: C0009
#   SimilarCustomerID: C0061, SimilarityScore: 0.9682
#   SimilarCustomerID: C0198, SimilarityScore: 0.9456
#   SimilarCustomerID: C0103, SimilarityScore: 0.9195
# --------------------------------------------------
# CustomerID: C0010
#   SimilarCustomerID: C0111, SimilarityScore: 0.9603
#   SimilarCustomerID: C0062, SimilarityScore: 0.8884
#   SimilarCustomerID: C0121, SimilarityScore: 0.8844
# --------------------------------------------------
# CustomerID: C0011
#   SimilarCustomerID: C0137, SimilarityScore: 0.9307
#   SimilarCustomerID: C0126, SimilarityScore: 0.9283
#   SimilarCustomerID: C0006, SimilarityScore: 0.8952
# --------------------------------------------------
# CustomerID: C0012
#   SimilarCustomerID: C0163, SimilarityScore: 0.9809
#   SimilarCustomerID: C0113, SimilarityScore: 0.9234
#   SimilarCustomerID: C0104, SimilarityScore: 0.9201
# --------------------------------------------------
# CustomerID: C0013
#   SimilarCustomerID: C0099, SimilarityScore: 0.9833
#   SimilarCustomerID: C0082, SimilarityScore: 0.8784
#   SimilarCustomerID: C0108, SimilarityScore: 0.8751
# --------------------------------------------------
# CustomerID: C0014
#   SimilarCustomerID: C0097, SimilarityScore: 0.9503
#   SimilarCustomerID: C0060, SimilarityScore: 0.9453
#   SimilarCustomerID: C0063, SimilarityScore: 0.9362
# --------------------------------------------------
# CustomerID: C0015
#   SimilarCustomerID: C0131, SimilarityScore: 0.9731
#   SimilarCustomerID: C0058, SimilarityScore: 0.9499
#   SimilarCustomerID: C0020, SimilarityScore: 0.8820
# --------------------------------------------------
# CustomerID: C0016
#   SimilarCustomerID: C0042, SimilarityScore: 0.9258
#   SimilarCustomerID: C0040, SimilarityScore: 0.8985
#   SimilarCustomerID: C0185, SimilarityScore: 0.8875
# --------------------------------------------------
# CustomerID: C0017
#   SimilarCustomerID: C0075, SimilarityScore: 0.9687
#   SimilarCustomerID: C0041, SimilarityScore: 0.9377
#   SimilarCustomerID: C0057, SimilarityScore: 0.8915
# --------------------------------------------------
# CustomerID: C0018
#   SimilarCustomerID: C0046, SimilarityScore: 0.9358
#   SimilarCustomerID: C0122, SimilarityScore: 0.9217
#   SimilarCustomerID: C0068, SimilarityScore: 0.8796
# --------------------------------------------------
# CustomerID: C0019
#   SimilarCustomerID: C0073, SimilarityScore: 0.9870
#   SimilarCustomerID: C0132, SimilarityScore: 0.9287
#   SimilarCustomerID: C0063, SimilarityScore: 0.8873
# --------------------------------------------------
# CustomerID: C0020
#   SimilarCustomerID: C0140, SimilarityScore: 0.9056
#   SimilarCustomerID: C0005, SimilarityScore: 0.8956
#   SimilarCustomerID: C0131, SimilarityScore: 0.8913
# --------------------------------------------------
